# %%
import re
import numpy as np
import pandas as pd
from keras.models import *
from keras.layers import *
from keras.layers import *
from keras import optimizers
from keras.utils import np_utils
from keras.callbacks import TensorBoard
from keras.models import load_model
import math
import os.path
# Out:
# Using TensorFlow backend.
# /Users/Zizy/anaconda/envs/tensorflow/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)

# %%
local_path='/Users/Zizy/Programming/HKU/Dissertation/'

# %%
def read_sp():
    sps = None
    for i in range(0, 4):
        sp_file_name = 'nitech_jp_song070_f001_0' + (('0' + str(i)) if i < 10 else str(i)) + '_sp.txt'
        if not os.path.isfile(local_path + 'gen/' + sp_file_name):
            continue
        with open(local_path + 'gen/' + sp_file_name, 'r') as sp_file:
            lines = sp_file.readlines()
            lines = np.array(lines)
            i=0
            for line in lines:
                i+=1
                if i%1000==0 :
                    print("%s/%s"%(i,len(lines))) 
                    print(sps.shape)
                sp = np.array(line.split(',')).astype(float)
                sps = [sp] if sps is None else np.vstack([sps,sp])

    # sps = np.array(sps)

    return sps

# %%
sps = read_sp()
# Out:
# 1000/6240
# (999, 1025)
# 2000/6240
# (1999, 1025)
# 3000/6240
# (2999, 1025)
# 4000/6240
# (3999, 1025)
# 5000/6240
# (4999, 1025)
# 6000/6240
# (5999, 1025)

# %%
sps = np.array([])
np.append(sps,np.array([1,2,3]))
# Out:
# array([1., 2., 3.])

# %%
inputs = Input(shape=(1025,))

# a layer instance is callable on a tensor, and returns a tensor
x = BatchNormalization()(inputs)
x = Dense(512, activation='relu')(x)
x = Dense(512, activation='relu')(x)
decoded = Dense(1025, activation='linear')(x)

model = Model(inputs=inputs, output=decoded)
model.compile(optimizer='adam',
              loss='mse',
              metrics=['mae', 'acc']

              )
model.fit(sps, sps, nb_epoch=2000, batch_size=20, validation_split=0.1, )
# Out:
# /Users/Zizy/anaconda/envs/tensorflow/lib/python3.5/site-packages/ipykernel_launcher.py:9: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   if __name__ == '__main__':
# /Users/Zizy/anaconda/envs/tensorflow/lib/python3.5/site-packages/ipykernel_launcher.py:15: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   from ipykernel import kernelapp as app
# Train on 5616 samples, validate on 624 samples
# Epoch 1/2000
# ...
# 5616/5616 [==============================] - 5s 927us/step - loss: 2.6040e-04 - mean_absolute_error: 0.0042 - acc: 0.0949 - val_loss: 5.8951e-06 - val_mean_absolute_error: 9.6076e-04 - val_acc: 0.2340
# Epoch 2/2000
# ...
# 5616/5616 [==============================] - 4s 772us/step - loss: 8.7956e-05 - mean_absolute_error: 0.0019 - acc: 0.1015 - val_loss: 3.0015e-06 - val_mean_absolute_error: 6.5283e-04 - val_acc: 0.2324
# Epoch 3/2000
# ...

# %%
def read_sp():
    max_sp_size = 0
    sps = []
    for i in range(0, 71):
        sp_file_name = 'nitech_jp_song070_f001_0' + (('0' + str(i)) if i < 10 else str(i)) + '_sp.txt'
        if not os.path.isfile(local_path + 'gen/' + sp_file_name):
            continue
        with open(local_path + 'gen/' + sp_file_name, 'r') as sp_file:
            lines = sp_file.readlines()
            lines = np.array(lines)
            new_lines = []
            for line in lines:
                new_lines.append(np.array(line.split(',')).astype(float))
            new_lines = np.array(new_lines)
            if len(lines) > max_sp_size:
                max_sp_size = len(lines)
            sps.append(new_lines)
            print(len(sps))

    # 即要生成的最多个sp，
    print(max_sp_size)

    for index, sp in enumerate(sps):
        sps[index]=np.vstack([sps[index], np.zeros((max_sp_size-len(sp),1025))])
    sps = np.array(sps)
    # sps = np.reshape(sps, (sps.shape[0], sps.shape[1], 1025))

    # (31, max_sp_size, 1)
    return sps, max_sp_size

# %%
sps, _ = read_sp()
# Out:
# 1
# 2
# 3
# 8640

# %%
sps.shape
# Out:
# (3, 8640, 1025)

# %%
# Out:
# (6242, 1025)

# %%
sps[0]
# Out:
# array([8640, 1025])

# %%
np.zeros((1025,1)).shape
# Out:
# (1025, 1)
